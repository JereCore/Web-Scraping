# %% [markdown]
# ***SCRAP ANIMELIST***

# %%
import requests
import lxml.html as html
import pandas as pd
import numpy as np

from collections import defaultdict

# %%
url_padre = "https://myanimelist.net/anime/season"

# %%
#Obteniendo titulos y score de estrenos animes de temporada
temporada = '//h1//a[@class="on"]/text()'
titulo_temporada = '//div[2]/div[3]/div[1]//a[@class="link-title"]/text()'
score_temporada = '//div[2]/div[3]/div[1]//div[@title="Score"]/text()'
imagenes_temporada = '//div[2]/div[3]/div[1]//div[@class="image"]//a//@src'
#Obteniendo titulos de animes en emisión.
# titulo_emision =  '//div[@class="product_price"]/p[@class="price_color"]/text()'

#Obteniendo Categoria
# categoria = '//div[@class="page-header action"]/h1/text()'

# %%
#requests
r = requests.get(url_padre)
print(r.status_code)
# Out:
# 200

# %% [markdown]
# #### __RESPUESTA HTTP__
#
# * Respuestas informativas (100–199),
# * Respuestas satisfactorias (200–299),
# * Redirecciones (300–399),
# * Errores de los clientes (400–499),
# * y errores de los servidores (500–599).

# %% [markdown]
# *REQUEST MANUALES DE PRUEBA*

# %%
#requests

r = requests.get(url_padre)

home = r.content.decode("utf-8")

parser = html.fromstring(home)

#Temporada 
temporada_analisis = parser.xpath(temporada)
temporada_analisis = list(map(lambda x: x.replace('\n', ''), temporada_analisis))
temporada_analisis = [x.strip() for x in temporada_analisis]
temporada_analisis

#Titulos anime temporada
titulos_anime_streno_temporada = parser.xpath(titulo_temporada)

#Score anime temporada
score_anime_streno_temporada = parser.xpath(score_temporada)
score_anime_streno_temporada = [x for x in score_anime_streno_temporada if x != '\n          ']
score_anime_streno_temporada = list(map(lambda x: x.replace('\n        ', ''), score_anime_streno_temporada))

#Imagenes animes
# imagenes_anime_temporada = parser.xpath(imagenes_temporada)

# %% [markdown]
# **Rutina para obtener imagenes***

# %%
#Imagenes animes

from lxml import html 
imagenes_dic = []
tree = html.fromstring(home)
for link_element in tree.xpath('//div[2]/div[3]/div[1]//div[@class="image"]//a/img'):
    # href1 = link_element.get('src')
    # print(type(href1))
    if (link_element.get('src') is None):
        href1 = link_element.get('data-src')
        imagenes_dic.append(href1)
        # print(href1)
    else:
        href1 = link_element.get('src')
        imagenes_dic.append(href1)
        # print(href1)

len(imagenes_dic)
# Out:
# 54

# %% [markdown]
# __FUNCIÓN ANIME TEMPORADA__

# %%
def parser_anime_temporada(url): 
    content_dic = {}
    r = requests.get(url)
    home = r.content.decode("utf-8")
    parser = html.fromstring(home)   

    if r.status_code == 200:
        
        #OBTENIENDO TITULOS Y PRECIO
        
        titulo_temporada = '//div[2]/div[3]/div[1]//a[@class="link-title"]/text()'
        titulos_anime_streno_temporada = parser.xpath(titulo_temporada)
        content_dic['Anime Season'] = titulos_anime_streno_temporada

        score_temporada = '//div[2]/div[3]/div[1]//div[@title="Score"]/text()'
        score_anime_streno_temporada = parser.xpath(score_temporada)
        score_anime_streno_temporada = [x for x in score_anime_streno_temporada if x != '\n          ']
        score_anime_streno_temporada = list(map(lambda x: x.replace('\n        ', ''), score_anime_streno_temporada))
        content_dic['Score Anime Season'] = score_anime_streno_temporada

        temporada = '//h1//a[@class="on"]/text()'
        temporada_analisis = parser.xpath(temporada)
        temporada_analisis = list(map(lambda x: x.replace('\n', ''), temporada_analisis))
        temporada_analisis = [x.strip() for x in temporada_analisis]
        
    imagenes_temporada = []
    # tree = html.fromstring(home)
    for link_element in parser.xpath('//div[2]/div[3]/div[1]//div[@class="image"]//a/img'):
        # href1 = link_element.get('src')
        # print(type(href1))
        if (link_element.get('src') is None):
            href1 = link_element.get('data-src')
            imagenes_temporada.append(href1)
            # print(href1)
        else:
            href1 = link_element.get('src')
            imagenes_temporada.append(href1)
        # print(href1)

    content_dic['Imagenes'] = []
    content_dic.update({"Imagenes": imagenes_temporada})


    list_temporada = []
    for j in range(len(content_dic['Anime Season'])):
        
        list_temporada.append(temporada_analisis)

    content_dic['Temporada'] = []
    content_dic.update({"Temporada": list_temporada})

    return content_dic

# %%
data = []
data.append(parser_anime_temporada(url_padre))

# %% [markdown]
# __Creando Dataframe__

# %%
df = pd.DataFrame()
for j in data:
    df_uno = pd.DataFrame(j)
    df = pd.concat([df, df_uno])

df
# Out:
#                                          Anime Season Score Anime Season  \
# 0                                        Spy x Family               9.08
# 1                Tate no Yuusha no Nariagari Season 2               7.33
# 2          Kaguya-sama wa Kokurasetai: Ultra Romantic               8.96
# 3                    Kawaii dake ja Nai Shikimori-san               7.23
# 4             Komi-san wa, Comyushou desu. 2nd Season               8.32
# 5                             Aharen-san wa Hakarenai               7.49
# 6                                      Date A Live IV               8.01
# 7                                    Yuusha, Yamemasu               7.09
# 8                                      Tomodachi Game               7.23
# 9   Gaikotsu Kishi-sama, Tadaima Isekai e Odekakechuu               7.32
# 10                                  Summertime Render               8.26
# 11  Shijou Saikyou no Daimaou, Murabito A ni Tense...               6.90
# 12                                 Kakkou no Iinazuke               7.68
# 13  Rikei ga Koi ni Ochita no de Shoumei shitemita...               7.50
# 14     Otome Game Sekai wa Mob ni Kibishii Sekai desu               7.11
# 15                     Koi wa Sekai Seifuku no Ato de               7.45
# 16                                      Paripi Koumei               8.36
# 17  Honzuki no Gekokujou: Shisho ni Naru Tame ni w...               8.04
# 18                       Shokei Shoujo no Virgin Road               6.92
# 19                               Mahoutsukai Reimeiki               6.32
# 20                                            Ao Ashi               7.66
# 21                                            Deaimon               7.51
# 22                         Machikado Mazoku: 2-choume               7.78
# 23                                Dance Dance Danseur               7.51
# 24  Heroine Tarumono! Kiraware Heroine to Naisho n...               7.19
# 25                   Kunoichi Tsubaki no Mune no Uchi               6.67
# 26                    Black★★Rock Shooter:  Dawn Fall               5.75
# 27                            Kono Healer, Mendokusai               5.80
# 28                                      Love All Play               6.63
# 29                                       RPG Fudousan               6.37
# 30  Love Live! Nijigasaki Gakuen School Idol Douko...               7.96
# 31                                 Kingdom 4th Season               8.70
# 32        Shachiku-san wa Youjo Yuurei ni Iyasaretai.               7.02
# 26  https://cdn.myanimelist.net/images/anime/1549/...  [Spring 2022]
# 27  https://cdn.myanimelist.net/images/anime/1565/...  [Spring 2022]
# 28  https://cdn.myanimelist.net/images/anime/1346/...  [Spring 2022]
# 29  https://cdn.myanimelist.net/images/anime/1680/...  [Spring 2022]
# 30  https://cdn.myanimelist.net/images/anime/1586/...  [Spring 2022]
# 31  https://cdn.myanimelist.net/images/anime/1566/...  [Spring 2022]
# 32  https://cdn.myanimelist.net/images/anime/1190/...  [Spring 2022]
# 33  https://cdn.myanimelist.net/images/anime/1769/...  [Spring 2022]
# 34  https://cdn.myanimelist.net/images/anime/1064/...  [Spring 2022]
# 35  https://cdn.myanimelist.net/images/anime/1727/...  [Spring 2022]
# 36  https://cdn.myanimelist.net/images/anime/1248/...  [Spring 2022]
# 37  https://cdn.myanimelist.net/images/anime/1194/...  [Spring 2022]
# 38  https://cdn.myanimelist.net/images/anime/1278/...  [Spring 2022]
# 39  https://cdn.myanimelist.net/images/anime/1452/...  [Spring 2022]
# 40  https://cdn.myanimelist.net/images/anime/1968/...  [Spring 2022]
# 41  https://cdn.myanimelist.net/images/anime/1811/...  [Spring 2022]
# 42  https://cdn.myanimelist.net/images/anime/1549/...  [Spring 2022]
# 43  https://cdn.myanimelist.net/images/anime/1445/...  [Spring 2022]
# 44  https://cdn.myanimelist.net/images/anime/1960/...  [Spring 2022]
# 45  https://cdn.myanimelist.net/images/anime/1556/...  [Spring 2022]
# 46  https://cdn.myanimelist.net/images/anime/1877/...  [Spring 2022]
# 47  https://cdn.myanimelist.net/images/anime/1783/...  [Spring 2022]
# 48  https://cdn.myanimelist.net/images/anime/1957/...  [Spring 2022]
# 49  https://cdn.myanimelist.net/images/anime/1699/...  [Spring 2022]
# 50  https://cdn.myanimelist.net/images/anime/1191/...  [Spring 2022]
# 51  https://cdn.myanimelist.net/images/anime/1186/...  [Spring 2022]
# 52  https://cdn.myanimelist.net/images/anime/1991/...  [Spring 2022]
# 53  https://cdn.myanimelist.net/images/anime/1755/...  [Spring 2022]

# %%
from IPython.core.display import HTML

def path_html_img(url):
    return '<img src="' + url + '"width = "60">'

# %%
df['Imagen_vista'] = df['Imagenes'].apply(lambda x : path_html_img(x))
df.head()
# Out:
#                                  Anime Season Score Anime Season  \
# 0                                Spy x Family               9.08
# 1        Tate no Yuusha no Nariagari Season 2               7.33
# 2  Kaguya-sama wa Kokurasetai: Ultra Romantic               8.96
# 3            Kawaii dake ja Nai Shikimori-san               7.23
# 4     Komi-san wa, Comyushou desu. 2nd Season               8.32
#
#                                             Imagenes      Temporada  \
# 0  https://cdn.myanimelist.net/images/anime/1441/...  [Spring 2022]
# 1  https://cdn.myanimelist.net/images/anime/1143/...  [Spring 2022]
# 2  https://cdn.myanimelist.net/images/anime/1160/...  [Spring 2022]
# 3  https://cdn.myanimelist.net/images/anime/1995/...  [Spring 2022]
# 4  https://cdn.myanimelist.net/images/anime/1108/...  [Spring 2022]
#
#                                         Imagen_vista
# 0  <img src="https://cdn.myanimelist.net/images/a...
# 1  <img src="https://cdn.myanimelist.net/images/a...
# 2  <img src="https://cdn.myanimelist.net/images/a...
# 3  <img src="https://cdn.myanimelist.net/images/a...
# 4  <img src="https://cdn.myanimelist.net/images/a...

# %%
# df.to_html(escape=False, formatters=dict(Portada = path_html_img))

# %%
HTML(df.to_html(escape=False, formatters=dict(Portada = path_html_img)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Anime Season</th>
#       <th>Score Anime Season</th>
#       <th>Imagenes</th>
#       <th>Temporada</th>
#       <th>Imagen_vista</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Spy x Family</td>
#       <td>9.08</td>
#       <td>https://cdn.myanimelist.net/images/anime/1441/122795.jpg</td>
#       <td>[Spring 2022]</td>
#       <td><img src="https://cdn.myanimelist.net/images/anime/1441/122795.jpg"width = "60"></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Tate no Yuusha no Nariagari Season 2</td>
#       <td>7.33</td>
#       <td>https://cdn.myanimelist.net/images/anime/1143/121873.jpg</td>
#       <td>[Spring 2022]</td>
#       <td><img src="https://cdn.myanimelist.net/images/anime/1143/121873.jpg"width = "60"></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Kaguya-sama wa Kokurasetai: Ultra Romantic</td>
#       <td>8.96</td>
#       <td>https://cdn.myanimelist.net/images/anime/1160/122627.jpg</td>
#       <td>[Spring 2022]</td>
#       <td><img src="https://cdn.myanimelist.net/images/anime/1160/122627.jpg"width = "60"></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Kawaii dake ja Nai Shikimori-san</td>
#       <td>7.23</td>
#       <td>https://cdn.myanimelist.net/images/anime/1995/121695.jpg</td>
#       <td>[Spring 2022]</td>
#       <td><img src="https://cdn.myanimelist.net/images/anime/1995/121695.jpg"width = "60"></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Komi-san wa, Comyushou desu. 2nd Season</td>
#       <td>8.32</td>
#       <td>https://cdn.myanimelist.net/images/anime/1108/121157.jpg</td>
#       <td>[Spring 2022]</td>
#       <td><img src="https://cdn.myanimelist.net/images/anime/1108/121157.jpg"width = "60"></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Aharen-san wa Hakarenai</td>
#       <td>7.49</td>
#       <td>https://cdn.myanimelist.net/images/anime/1612/120636.jpg</td>
#       <td>[Spring 2022]</td>
#       <td><img src="https://cdn.myanimelist.net/images/anime/1612/120636.jpg"width = "60"></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Date A Live IV</td>
#       <td>8.01</td>
#       <td>https://cdn.myanimelist.net/images/anime/1368/121281.jpg</td>
#       <td>[Spring 2022]</td>
#       <td><img src="https://cdn.myanimelist.net/images/anime/1368/121281.jpg"width = "60"></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Yuusha, Yamemasu</td>
#       <td>7.09</td>
#       <td>https://cdn.myanimelist.net/images/anime/1934/122301.jpg</td>
